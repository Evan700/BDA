# %% [markdown]
# <a href="https://colab.research.google.com/github/Evan700/BDA/blob/main/ICP_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Evan Finger ICP 3

# %% [markdown]
# ### 1., 2.

# %%
import numpy as np
import pandas as pd
data = {
    'ID' : np.arange(1, 1000001),
    'Value': np.random.rand(1000000),
    'Category': np.random.choice(['A', 'B', 'C'], size=1000000)
}
df=pd.DataFrame(data)
df.head(10)
# Out:
#    ID     Value Category
# 0   1  0.427572        B
# 1   2  0.913909        C
# 2   3  0.098951        A
# 3   4  0.561866        B
# 4   5  0.991237        A
# 5   6  0.090347        A
# 6   7  0.715886        A
# 7   8  0.527466        A
# 8   9  0.691710        C
# 9  10  0.956815        B

# %% [markdown]
# ### 3.

# %%
df.Value
# Out:
# 0         0.840779
# 1         0.050318
# 2         0.858049
# 3         0.433742
# 4         0.549176
#             ...
# 999995    0.134063
# 999996    0.484533
# 999997    0.604635
# 999998    0.781681
# 999999    0.778594
# Name: Value, Length: 1000000, dtype: float64

# %% [markdown]
# ### 4.

# %%
df = df.rename(columns={'ID': 'ID number', 'Value': 'Random value', 'Category': 'Choice'})
df.head(5)
# Out:
#    ID number  Random value Choice
# 0          1      0.840779      B
# 1          2      0.050318      B
# 2          3      0.858049      C
# 3          4      0.433742      C
# 4          5      0.549176      C

# %% [markdown]
# ### 5.

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_rows', None)
student_data = pd.DataFrame({
    'school_code': ['s001', 's002', 's003', 's001', 's002', 's004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco', 'Gino Mcneill', 'Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_of_Birth ' : ['15/05/2002', '17/05/2002', '16/02/1999', '25/09/1998', '11/05/2002', '15/09/1997'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street 1', 'street2', 'street3', 'street1', 'street2', 'street4']},
    index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6'])
print("Original DataFrame: ")
print(student_data)
print('\nSplit the said data on school_code, class wise: ')
result = student_data.groupby(['school_code', 'class'])
for name,group in result:
  print("\nGroup: ")
  print(name)
  print(group)
# Out:
# Original DataFrame:
#    school_code class            name date_of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
# S2        s002     V    Gino Mcneill     17/05/2002   12     192      32
# S3        s003    VI     Ryan Parkes     16/02/1999   13     186      33
# S4        s001    VI    Eesha Hinton     25/09/1998   13     167      30
# S5        s002     V    Gino Mcneill     11/05/2002   14     151      31
# S6        s004    VI    David Parkes     15/09/1997   12     159      32
#
#      address
# S1  street 1
# S2   street2
# S3   street3
# S4   street1
# S5   street2
# S6   street4
#
# Split the said data on school_code, class wise:
#
# Group:
# ('s001', 'V')
#    school_code class            name date_of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
#
#      address
# S1  street 1
#
# Group:
# ('s001', 'VI')
# ...

# %% [markdown]
# add '' to VI;
# add : after address;
# turn student.groupby to student_data.groupby

# %% [markdown]
# ### 6.

# %%
csv = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/data.csv")

# %% [markdown]
# ### 7.

# %%
csv.describe()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %% [markdown]
# ### 8.

# %%
csv.isnull()
csv.fillna(csv.mean(), inplace=True)

# %% [markdown]
# ### 9.

# %%
columns = csv[['Duration', 'Pulse']]
columns.agg(['min', 'max', 'count', 'mean'])
# Out:
#          Duration       Pulse
# min     15.000000   80.000000
# max    300.000000  159.000000
# count  169.000000  169.000000
# mean    63.846154  107.461538

# %% [markdown]
# ### 10.

# %%
csv[(csv["Calories"] > 500) & (csv["Calories"] < 1000)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %% [markdown]
# ### 11.

# %%
csv[(csv["Calories"] > 500) & (csv["Pulse"] < 100)]

# %% [markdown]
# ### 12.

# %%
df_modified = csv[['Duration', 'Pulse', 'Calories']]
df_modified.head()
# Out:
#    Duration  Pulse  Calories
# 0        60    110     409.1
# 1        60    117     479.0
# 2        60    103     340.0
# 3        45    109     282.4
# 4        45    117     406.0

# %% [markdown]
# ### 13.

# %%
csv.drop("Maxpulse", axis=1, inplace=True)
csv.head()

# %% [markdown]
# ### 14.

# %%
csv["Calories"] = csv["Calories"].astype(int)
csv.head()

# %% [markdown]
# ### 15.

# %%
import matplotlib.pyplot as plt
csv.plot(kind='scatter', x='Duration', y='Calories', color='blue')
# Out:
# <Axes: xlabel='Duration', ylabel='Calories'>
